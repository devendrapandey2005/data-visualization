# %% [markdown]
# <a href="https://colab.research.google.com/github/devendrapandey2005/data-visualization/blob/main/student_performance_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
df.rename(columns = {'race/ethnicity':'groups'},inplace = True)

# %%
df
# Out:
#      gender    group parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %% [markdown]
# GROUP BY

# %%
groups = df.groupby('groups')#this create a group by object

# %%
print(groups)#address of the group

# %%
for group,df in groups:
  print(df)
  print(group)
# Out:
#      gender   groups parental level of education         lunch  \
# 32   female  group E             master's degree  free/reduced
# 34     male  group E                some college      standard
# 35     male  group E          associate's degree      standard
# 44   female  group E          associate's degree  free/reduced
# 50     male  group E                some college      standard
# ..      ...      ...                         ...           ...
# 962  female  group E          associate's degree      standard
# 968  female  group E          associate's degree      standard
# 987    male  group E            some high school      standard
# 990    male  group E                 high school  free/reduced
# 995  female  group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 32                     none          56             72             65
# ...

# %%
groups.sum(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group E       10335          10224           9997

# %%
groups.mean(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group E   73.821429      73.028571      71.407143

# %%
groups.var(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group E  241.313207     221.236588     228.430164

# %%
groups.max(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group E         100            100            100

# %%
groups.count()
# Out:
#          gender  parental level of education  lunch  test preparation course  \
# groups
# group E     140                          140    140                      140
#
#          math score  reading score  writing score
# groups
# group E         140            140            140

# %%
#find that group which scored highest total in math
print(groups['math score'].sum().sort_values().tail(1))
# Out:
# groups
# group E    10335
# Name: math score, dtype: int64

# %%
#find that group scored highest avg in writing
print(groups['writing score'].mean().sort_values().tail(1))
# Out:
# groups
# group E    71.407143
# Name: writing score, dtype: float64

# %%
#find that perental level of education which has highest total in reading score
print(df.groupby('parental level of education')['reading score'].sum().sort_values().tail(1))
# Out:
# parental level of education
# associate's degree    2879
# Name: reading score, dtype: int64

# %%
df.sample()
# Out:
#      gender   groups parental level of education     lunch  \
# 915  female  group E                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 915                    none          68             70             66

# %% [markdown]
# groups yeh batata hai ki column ka data kis kis index pr present hai

# %%
df.groupby('parental level of education').groups
# Out:
# {'associate's degree': [35, 44, 51, 56, 83, 107, 149, 190, 216, 246, 286, 297, 332, 349, 375, 479, 503, 532, 533, 554, 691, 719, 726, 755, 779, 795, 797, 802, 868, 873, 884, 886, 891, 894, 926, 928, 955, 962, 968], 'bachelor's degree': [60, 114, 206, 241, 293, 386, 458, 476, 538, 566, 592, 616, 624, 700, 757, 881, 909, 916], 'high school': [137, 156, 182, 186, 197, 207, 214, 263, 277, 321, 415, 419, 574, 593, 643, 647, 807, 836, 937, 949, 950, 990], 'master's degree': [32, 79, 164, 225, 685, 845, 861, 995], 'some college': [34, 50, 97, 124, 132, 142, 161, 243, 255, 269, 306, 351, 370, 385, 392, 411, 451, 462, 499, 517, 525, 602, 608, 638, 676, 686, 689, 725, 734, 751, 798, 822, 852, 890, 915], 'some high school': [76, 171, 233, 289, 383, 390, 545, 581, 711, 727, 786, 793, 813, 853, 895, 925, 952, 987]}

# %%
df.groupby('gender').ngroups
# Out:
# 2

# %%
df.groupby('groups').ngroups
# Out:
# 1

# %%
len(df.groupby('groups'))
# Out:
# 5

# %%
df.groupby('groups').size()
# Out:
# groups
# group A     89
# group B    190
# group C    319
# group D    262
# group E    140
# dtype: int64

# %%
groups.indices
# Out:
# {'group A': array([  3,  13,  14,  25,  46,  61,  62,  72,  77,  82,  88, 112, 129,
#         143, 150, 151, 170, 228, 250, 296, 300, 305, 327, 356, 365, 368,
#         378, 379, 384, 395, 401, 402, 423, 428, 433, 442, 444, 464, 467,
#         468, 483, 489, 490, 506, 511, 539, 546, 571, 575, 576, 586, 589,
#         591, 597, 614, 623, 635, 651, 653, 688, 697, 702, 705, 731, 741,
#         769, 778, 805, 810, 811, 816, 820, 830, 832, 837, 851, 892, 902,
#         911, 936, 943, 960, 966, 972, 974, 983, 985, 988, 994]),
#  'group B': array([  0,   2,   5,   6,   7,   9,  12,  17,  21,  26,  31,  39,  42,
#          43,  45,  65,  68,  75,  80,  81,  94,  96, 100, 103, 108, 109,
#         116, 121, 125, 126, 136, 146, 152, 157, 158, 160, 162, 167, 168,
#         176, 178, 188, 192, 198, 199, 203, 208, 209, 215, 218, 219, 221,
#         224, 232, 238, 247, 248, 252, 258, 274, 279, 284, 285, 287, 288,
#         295, 303, 308, 310, 311, 318, 329, 333, 335, 338, 342, 346, 350,
# ...

# %%
df['math score'].nunique()
# Out:
# 81

# %%
print(groups['math score'].unique().loc['group D'])
# Out:
# [ 64  40  66  44  74  62  69  50  75  57  88  52  58  59  45  63  61  42
#   71  73  65  68  85  87  77  51  78  82  89  76  54  79  97  80  56  86
#   47  53  70  90  49  67  35  27  60  26  55  29  81  84  95 100  41  43
#   46  98  72  48  39  93  92]

# %%
groups.count()
# Out:
#          gender  parental level of education  lunch  test preparation course  \
# groups
# group A      89                           89     89                       89
# group B     190                          190    190                      190
# group C     319                          319    319                      319
# group D     262                          262    262                      262
# group E     140                          140    140                      140
#
#          math score  reading score  writing score
# groups
# group A          89             89             89
# group B         190            190            190
# group C         319            319            319
# group D         262            262            262
# group E         140            140            140

# %%
groups.first()
# Out:
#          gender parental level of education         lunch  \
# groups
# group A    male          associate's degree  free/reduced
# group B  female           bachelor's degree      standard
# group C  female                some college      standard
# group D    male                 high school  free/reduced
# group E  female             master's degree  free/reduced
#
#         test preparation course  math score  reading score  writing score
# groups
# group A                    none          47             57             44
# group B                    none          72             72             74
# group C               completed          69             90             88
# group D               completed          64             64             67
# group E                    none          56             72             65

# %%
groups.last()
# Out:
#          gender parental level of education         lunch  \
# groups
# group A    male                 high school      standard
# group B  female            some high school      standard
# group C  female                 high school  free/reduced
# group D  female                some college  free/reduced
# group E  female             master's degree      standard
#
#         test preparation course  math score  reading score  writing score
# groups
# group A                    none          63             63             62
# group B               completed          65             82             78
# group C               completed          59             71             65
# group D                    none          77             86             86
# group E               completed          88             99             95

# %%
groups.get_group('group A')
# Out:
#      gender   groups parental level of education         lunch  \
# 3      male  group A          associate's degree  free/reduced
# 13     male  group A                some college      standard
# 14   female  group A             master's degree      standard
# 25     male  group A             master's degree  free/reduced
# 46   female  group A          associate's degree      standard
# ..      ...      ...                         ...           ...
# 974  female  group A                some college      standard
# 983  female  group A                some college      standard
# 985    male  group A                 high school      standard
# 988  female  group A            some high school  free/reduced
# 994    male  group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
groups.get_group('group A').head(5)
# Out:
#     gender   groups parental level of education         lunch  \
# 3     male  group A          associate's degree  free/reduced
# 13    male  group A                some college      standard
# 14  female  group A             master's degree      standard
# 25    male  group A             master's degree  free/reduced
# 46  female  group A          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 13               completed          78             72             70
# 14                    none          50             53             58
# 25                    none          73             74             72
# 46               completed          55             65             62

# %%
groups.agg(
    {
        'math score':'max',
        'reading score':'mean',
        'writing score':'sum'
    }
)
# Out:
#          math score  reading score  writing score
# groups
# group A         100      64.674157           5578
# group B          97      67.352632          12464
# group C          98      69.103448          21637
# group D         100      70.030534          18378
# group E         100      73.028571           9997

# %%
groups.agg(
    {
        'math score':['max','min'],
        'reading score':['mean','std'],
        'writing score':['sum','min','max']
    }
)
# Out:
#         math score     reading score            writing score
#                max min          mean        std           sum min  max
# groups
# group A        100  28     64.674157  15.543762          5578  19   97
# group B         97   8     67.352632  15.177499         12464  15   96
# group C         98   0     69.103448  13.997033         21637  10  100
# group D        100  26     70.030534  13.895306         18378  32  100
# group E        100  30     73.028571  14.874024          9997  22  100
