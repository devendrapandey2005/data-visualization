# %% [markdown]
# <a href="https://colab.research.google.com/github/devendrapandey2005/data-visualization/blob/main/tips_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
df.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 30        9.55  1.45  Male     No  Sat  Dinner     2

# %%
df.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 5.75        1.00   Female  Yes     Fri   Dinner  2       1
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 7.25        5.15   Male    Yes     Sun   Dinner  2       1
# 7.51        2.00   Male    No      Thur  Lunch   2       1
#                                                         ..
# 45.35       3.50   Male    Yes     Sun   Dinner  3       1
# 48.17       5.00   Male    No      Sun   Dinner  6       1
# 48.27       6.73   Male    No      Sat   Dinner  4       1
# 48.33       9.00   Male    No      Sat   Dinner  4       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Name: count, Length: 243, dtype: int64

# %%
df.value_counts('smoker')
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
print(df['smoker'].unique())
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
print(df['tip'].unique())
# Out:
# [ 1.01  1.66  3.5   3.31  3.61  4.71  2.    3.12  1.96  3.23  1.71  5.
#   1.57  3.    3.02  3.92  1.67  3.71  3.35  4.08  2.75  2.23  7.58  3.18
#   2.34  4.3   1.45  2.5   2.45  3.27  3.6   3.07  2.31  2.24  2.54  3.06
#   1.32  5.6   6.    2.05  2.6   5.2   1.56  4.34  3.51  1.5   1.76  6.73
#   3.21  1.98  3.76  2.64  3.15  2.47  1.    2.01  2.09  1.97  3.14  2.2
#   1.25  3.08  4.    2.71  3.4   1.83  2.03  5.17  5.85  3.25  4.73  3.48
#   1.64  4.06  4.29  2.55  5.07  1.8   2.92  1.68  2.52  4.2   1.48  2.18
#   2.83  6.7   2.3   1.36  1.63  1.73  2.74  5.14  3.75  2.61  4.5   1.61
#  10.    3.16  5.15  3.11  3.55  3.68  5.65  6.5   4.19  2.56  2.02  1.44
#   3.41  5.16  9.    1.1   3.09  1.92  1.58  2.72  2.88  3.39  1.47  1.17
#   4.67  5.92  1.75]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['size'] = df['size'].astype('int32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int32
# dtypes: category(4), float64(2), int32(1)
# memory usage: 6.4 KB

# %%
df['tip'] = df['tip'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float32
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int32
# dtypes: category(4), float32(1), float64(1), int32(1)
# memory usage: 5.5 KB

# %%
df['total_bill'] = df['total_bill'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float32
#  1   tip         244 non-null    float32
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int32
# dtypes: category(4), float32(2), int32(1)
# memory usage: 4.5 KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    243
# True       1
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
df[(df['tip'] > 2) | (df['tip'] < 4)]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 0     16.990000  1.0  Female     No   Sun  Dinner     2
# 1     10.340000  1.0    Male     No   Sun  Dinner     3
# 2     21.010000  3.0    Male     No   Sun  Dinner     3
# 3     23.680000  3.0    Male     No   Sun  Dinner     2
# 4     24.590000  3.0  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239   29.030001  5.0    Male     No   Sat  Dinner     3
# 240   27.180000  2.0  Female    Yes   Sat  Dinner     2
# 241   22.670000  2.0    Male    Yes   Sat  Dinner     2
# 242   17.820000  1.0    Male     No   Sat  Dinner     2
# 243   18.780001  3.0  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.value_counts('tip')
# Out:
# tip
# 2.0     78
# 3.0     68
# 1.0     45
# 4.0     25
# 5.0     20
# 6.0      5
# 7.0      1
# 9.0      1
# 10.0     1
# Name: count, dtype: int64

# %% [markdown]
# univeriate analysis

# %%
df['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785940
# std        8.902413
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810001
# Name: total_bill, dtype: float64

# %%
sns.histplot(df['total_bill'],bins = 20)#bins ko jitna increase krenge utna accurate batayega
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>
